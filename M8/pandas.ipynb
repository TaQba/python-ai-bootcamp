# %% [markdown]
# Serie

# %%
import pandas as pd
exam1 = [89,85,93,83]
labels  = ['Student A', 'Student B', 'Student C', 'Student D']

# %%
pd.Series(exam1,labels) # buduj serie
# Out:
# Student A    89
# Student B    85
# Student C    93
# Student D    83
# dtype: int64

# %%
pd.Series(exam1,labels)['Student D'] # wyświetl jeden
# Out:
# np.int64(83)

# %%
d = {s:p for s,p in zip(labels,exam1)} # atlernatywa budowania serii

# %%
pd.Series(d)
# Out:
# Student A    89
# Student B    85
# Student C    93
# Student D    83
# dtype: int64

# %%
exam2 = [74,56,44,92] #nowe zmienne

e1 = pd.Series(exam1,labels)
e2 = pd.Series(exam2,labels)

# %%
e1 + e2 #operacja dodawania
# Out:
# Student A    163
# Student B    141
# Student C    137
# Student D    175
# dtype: int64

# %%
e1 * e2  #operacja mnozenia
# Out:
# Student A    6586
# Student B    4760
# Student C    4092
# Student D    7636
# dtype: int64

# %%
e2 / 5
# Out:
# Student A    14.8
# Student B    11.2
# Student C     8.8
# Student D    18.4
# dtype: float64

# %% [markdown]
# DataFrame

# %%
df = pd.DataFrame({'e1':exam1, 'e2':exam2},index=labels)
df
# Out:
#            e1  e2
# Student A  89  74
# Student B  85  56
# Student C  93  44
# Student D  83  92

# %%
df['e1']
# Out:
# Student A    89
# Student B    85
# Student C    93
# Student D    83
# Name: e1, dtype: int64

# %%
type(df['e1'])
# Out:
# pandas.core.series.Series

# %%
import numpy as np # wszystko identycznie jaka w numpy
data = np.array([exam1,exam2])
data.transpose()
# Out:
# array([[89, 74],
#        [85, 56],
#        [93, 44],
#        [83, 92]])

# %%
df.to_numpy()  #pandas 2 numpy
# Out:
# array([[89, 74],
#        [85, 56],
#        [93, 44],
#        [83, 92]])

# %%
df.shape # kszatl macierzy
# Out:
# (4, 2)

# %%
df['e1'] # zapis pierwszy
# Out:
# Student A    89
# Student B    85
# Student C    93
# Student D    83
# Name: e1, dtype: int64

# %%
df.e1  # zapis drugi
# Out:
# Student A    89
# Student B    85
# Student C    93
# Student D    83
# Name: e1, dtype: int64

# %%
df['e3'] = [67,59,79,84]
df
# Out:
#            e1  e2  e3
# Student A  89  74  67
# Student B  85  56  59
# Student C  93  44  79
# Student D  83  92  84

# %%
df['semester1'] = df['e1'] + df['e2'] + df['e3'] # dodanie 4 kolumny jak sumy 3 kolumn
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df[['e1','e2']] # więcej niż jedną kolumnę
# Out:
#            e1  e2
# Student A  89  74
# Student B  85  56
# Student C  93  44
# Student D  83  92

# %%
df.loc['Student C'] # dostep to wiersza
# Out:
# e1            93
# e2            44
# e3            79
# semester1    216
# Name: Student C, dtype: int64

# %%
df.loc['Student C','e2']
# Out:
# np.int64(44)

# %%
df.loc[['Student C','Student D'],['e2']]
# Out:
#            e2
# Student C  44
# Student D  92

# %%
df.iloc[1]
# Out:
# e1            85
# e2            56
# e3            59
# semester1    200
# Name: Student B, dtype: int64

# %%
df.iloc[1:,1]
# Out:
# Student B    56
# Student C    44
# Student D    92
# Name: e2, dtype: int64

# %% [markdown]
# Masking

# %%
df['e2'] > 70
# Out:
# Student A     True
# Student B    False
# Student C    False
# Student D     True
# Name: e2, dtype: bool

# %%
df[df['e2'] > 70] #filtrowanie
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student D  83  92  84        259

# %%
df[(df['e2']<50)|(df['e2']>90)]
# Out:
#            e1  e2  e3  semester1
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.drop('semester1',axis=1) #tylko filtruje a nie usuwa
# Out:
#            e1  e2  e3
# Student A  89  74  67
# Student B  85  56  59
# Student C  93  44  79
# Student D  83  92  84

# %%
df.drop(['e3','semester1'],axis=1,inplace=True) #tu usuwa bo inplace=True
df
# Out:
#            e1  e2
# Student A  89  74
# Student B  85  56
# Student C  93  44
# Student D  83  92

# %%
df.drop('Student B',inplace=True)
df
# Out:
#            e1  e2
# Student A  89  74
# Student C  93  44
# Student D  83  92

# %%
df.reset_index() # jeśli chcemy zachować zmiany, musimy użyć parametru inplace
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index = df.reset_index()
df_new_index
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index['student_name'] = ['Adrian','Bartłomiej','Celina','Dagmara']
df_new_index
# Out:
#        index  e1  e2  e3  semester1 student_name
# 0  Student A  89  74  67        230       Adrian
# 1  Student B  85  56  59        200   Bartłomiej
# 2  Student C  93  44  79        216       Celina
# 3  Student D  83  92  84        259      Dagmara

# %%
df_new_index.set_index('student_name')
# Out:
#                   index  e1  e2  e3  semester1
# student_name
# Adrian        Student A  89  74  67        230
# Bartłomiej    Student B  85  56  59        200
# Celina        Student C  93  44  79        216
# Dagmara       Student D  83  92  84        259

# %%
df_new_index2 = df.reset_index()
df_new_index2
# Out:
#        index  e1  e2  e3  semester1
# 0  Student A  89  74  67        230
# 1  Student B  85  56  59        200
# 2  Student C  93  44  79        216
# 3  Student D  83  92  84        259

# %%
df_new_index2.index = ['Adrian','Bartłomiej','Celina','Dagmara'] #nadpisanie indexu
df_new_index2
# Out:
#                 index  e1  e2  e3  semester1
# Adrian      Student A  89  74  67        230
# Bartłomiej  Student B  85  56  59        200
# Celina      Student C  93  44  79        216
# Dagmara     Student D  83  92  84        259

# %% [markdown]
# Funkcja rename – zmiana etykiet kolumn i wierszy

# %%
df.rename(columns={'e1':'exam1','e2':'exam2','e3':'exam3'})
# Out:
#            exam1  exam2  exam3  semester1
# Student A     89     74     67        230
# Student B     85     56     59        200
# Student C     93     44     79        216
# Student D     83     92     84        259

# %%
df.rename(index={'Studnet C':'Student C'})
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.rename(str.upper, axis='columns')
# Out:
#            E1  E2  E3  SEMESTER1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %% [markdown]
# Unique, value_counts, sort_values, drop_duplicates

# %%
df = pd.DataFrame({'A':[100,44,56,99,85,100],
                  'B':['Panda','Snake','Snake','Rat','Dog','Panda']})
df
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog
# 5  100  Panda

# %%
df['B'].unique()
# Out:
# array(['Panda', 'Snake', 'Rat', 'Dog'], dtype=object)

# %%
df['B'].nunique()
# Out:
# 4

# %%
df['B'].value_counts() #ile razy poszczególna wartość występuje w kolumnie
# Out:
# B
# Panda    2
# Snake    2
# Rat      1
# Dog      1
# Name: count, dtype: int64

# %%
df['B'].value_counts(normalize=True) #procentowy udział poszczególnych unikalnych kategorii
# Out:
# B
# Panda    0.333333
# Snake    0.333333
# Rat      0.166667
# Dog      0.166667
# Name: proportion, dtype: float64

# %%
df.sort_values(by='A') # sortowaniedf.drop_duplicates()
# Out:
#      A      B
# 1   44  Snake
# 2   56  Snake
# 4   85    Dog
# 3   99    Rat
# 0  100  Panda
# 5  100  Panda

# %%
df.sort_values(by='A',ascending=False)
# Out:
#      A      B
# 0  100  Panda
# 5  100  Panda
# 3   99    Rat
# 4   85    Dog
# 2   56  Snake
# 1   44  Snake

# %%
df.drop_duplicates() #usuwanie duplicatów
# Out:
#      A      B
# 0  100  Panda
# 1   44  Snake
# 2   56  Snake
# 3   99    Rat
# 4   85    Dog

# %% [markdown]
# MultiIndex

# %%
exam1 = [89,85,93,83]
exam2 = [74,56,44,92]
exam3=[67,59,79,84]
df = pd.DataFrame({'e1':exam1, 'e2':exam2, 'e3':exam3}, index=labels)
df['semester1'] = df['e1']+df['e2']+df['e3']
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
schools = ['High School X','High School X','High School Y','High School Y']
multi_index_list = [(school,student) for school,student in zip(schools,df.index)]
multi_index_list
# Out:
# [('High School X', 'Student A'),
#  ('High School X', 'Student B'),
#  ('High School Y', 'Student C'),
#  ('High School Y', 'Student D')]

# %%
df.index = pd.MultiIndex.from_tuples(multi_index_list,names=['School','Student']) #1 sposób
df
# Out:
#                          e1  e2  e3  semester1
# School        Student
# High School X Student A  89  74  67        230
#               Student B  85  56  59        200
# High School Y Student C  93  44  79        216
#               Student D  83  92  84        259

# %%
df.set_index([pd.Index(['High School X','High School X','High School Y','High School Y']), df.index],inplace=True) #2 sposób
df
# Out:
#                          e1  e2  e3  semester1
# High School X Student A  89  74  67        230
#               Student B  85  56  59        200
# High School Y Student C  93  44  79        216
#               Student D  83  92  84        259

# %%
df.index.names = ['School','Student'] #indeks wyższego poziomu, czyli nazwie szkoły. 
df
# Out:
#                          e1  e2  e3  semester1
# School        Student
# High School X Student A  89  74  67        230
#               Student B  85  56  59        200
# High School Y Student C  93  44  79        216
#               Student D  83  92  84        259

# %%
df.loc['High School X']
# Out:
#            e1  e2  e3  semester1
# Student
# Student A  89  74  67        230
# Student B  85  56  59        200

# %%
df.loc['High School X'].iloc[1]
# Out:
# e1            85
# e2            56
# e3            59
# semester1    200
# Name: Student B, dtype: int64

# %%
df.xs('High School Y')
# Out:
#            e1  e2  e3  semester1
# Student
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df.xs(('High School Y','Student D'))
# Out:
# e1            83
# e2            92
# e3            84
# semester1    259
# Name: (High School Y, Student D), dtype: int64

# %%
df.xs('Student D',level='Student')
# Out:
#                e1  e2  e3  semester1
# School
# High School Y  83  92  84        259

# %% [markdown]
# Zadanie:

# %%
exam4 = np.random.randint(1,100,4)
exam5 = np.random.randint(1,100,4)
exam6 = np.random.randint(1,100,4)

# %%
exam6
# Out:
# array([93, 36, 46, 42, 85])

# %%
df
# Out:
#            e1  e2  e3  semester1
# Student A  89  74  67        230
# Student B  85  56  59        200
# Student C  93  44  79        216
# Student D  83  92  84        259

# %%
df['e4'] = exam4
df['e5'] = exam5
df['e6'] = exam6
df
# Out:
#            e1  e2  e3  semester1  e4  e5  e6
# Student A  89  74  67        230  26  97  63
# Student B  85  56  59        200  72  95   7
# Student C  93  44  79        216  59  51  90
# Student D  83  92  84        259  39  11  87

# %%
df.drop(['semester1'],axis=1,inplace=True)
df
# Out:
#            e1  e2  e3  e4  e5  e6
# Student A  89  74  67  26  97  63
# Student B  85  56  59  72  95   7
# Student C  93  44  79  59  51  90
# Student D  83  92  84  39  11  87

# %%
columns = pd.MultiIndex.from_tuples([
    ('Sem1', 'e1'),
    ('Sem1', 'e2'),
    ('Sem1', 'e3'),
    ('Sem2', 'e4'),
    ('Sem2', 'e5'),
    ('Sem2', 'e6')
])
# Tworzenie DataFrame
da = pd.DataFrame(df, columns=columns)
da
# Out:
#   Sem1         Sem2
#     e1  e2  e3   e4  e5  e6
# 0  NaN NaN NaN  NaN NaN NaN
# 1  NaN NaN NaN  NaN NaN NaN
# 2  NaN NaN NaN  NaN NaN NaN
# 3  NaN NaN NaN  NaN NaN NaN
# 4  NaN NaN NaN  NaN NaN NaN
# 5  NaN NaN NaN  NaN NaN NaN

# %%
df
# Out:
#                          e1  e2  e3  e4  e5  e6
# School        Student
# High School X Student A  89  74  67  26  97  63
#               Student B  85  56  59  72  95   7
# High School Y Student C  93  44  79  59  51  90
#               Student D  83  92  84  39  11  87

# %%
df.index = pd.MultiIndex.from_tuples(multi_index_list,names=['School','Student'])

# %%
df
# Out:
#                          e1  e2  e3  e4  e5  e6
# School        Student
# High School X Student A  89  74  67  26  97  63
#               Student B  85  56  59  72  95   7
# High School Y Student C  93  44  79  59  51  90
#               Student D  83  92  84  39  11  87

# %%
df.columns.names = [None, None]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[146], line 1
# ----> 1 df.columns.names = [None, None]
#
# File ~/Code/venv312/lib/python3.12/site-packages/pandas/core/indexes/base.py:1787, in Index._set_names(self, values, level)
#    1785     raise ValueError("Names must be a list-like")
#    1786 if len(values) != 1:
# -> 1787     raise ValueError(f"Length of new names must be 1, got {len(values)}")
#    1789 # GH 20527
#    1790 # All items in 'name' need to be hashable:
#    1791 validate_all_hashable(*values, error_name=f"{type(self).__name__}.name")
#
# ValueError: Length of new names must be 1, got 2

# %% [markdown]
# Group BY

# %%
df = pd.DataFrame({'Category':['Games','Games','Games',

                               'Film&Video','Film&Video','Film&Video'],

                  'Project_Title':['The Last Faith','Magic Puzzles','Dinosaur Fossil Hunter',

                                   'Beyond Your Eyes','5150','8-Bit Wars'],

                  'Pledged':[92774,2873519,7962,

                             276,23963,6950],

                  'Country':['UK','USA','Poland',

                             'Bulgaria','USA','UK'],

                  'Date_Start':['2020-03-21','2020-03-11','2020-04-16',

                                '2020-02-09','2020-04-10','2020-03-19']})
df
# Out:
#      Category           Project_Title  Pledged   Country  Date_Start
# 0       Games          The Last Faith    92774        UK  2020-03-21
# 1       Games           Magic Puzzles  2873519       USA  2020-03-11
# 2       Games  Dinosaur Fossil Hunter     7962    Poland  2020-04-16
# 3  Film&Video        Beyond Your Eyes      276  Bulgaria  2020-02-09
# 4  Film&Video                    5150    23963       USA  2020-04-10
# 5  Film&Video              8-Bit Wars     6950        UK  2020-03-19

# %%
df.groupby('Category')

# %%
df.groupby('Category').sum()
# Out:
#                                                 Project_Title  Pledged  \
# Category
# Film&Video                     Beyond Your Eyes51508-Bit Wars    31189
# Games       The Last FaithMagic PuzzlesDinosaur Fossil Hunter  2974255
#
#                   Country                      Date_Start
# Category
# Film&Video  BulgariaUSAUK  2020-02-092020-04-102020-03-19
# Games         UKUSAPoland  2020-03-212020-03-112020-04-16

# %%
df.groupby('Category').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/Code/venv312/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File ~/Code/venv312/lib/python3.12/site-packages/pandas/core/groupby/ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File ~/Code/venv312/lib/python3.12/site-packages/pandas/core/groupby/ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
# ...

# %%
df.groupby('Category').count()
# Out:
#             Project_Title  Pledged  Country  Date_Start
# Category
# Film&Video              3        3        3           3
# Games                   3        3        3           3

# %%
df['Date_Start'] = pd.to_datetime(df['Date_Start'])
df
# Out:
#      Category           Project_Title  Pledged   Country Date_Start
# 0       Games          The Last Faith    92774        UK 2020-03-21
# 1       Games           Magic Puzzles  2873519       USA 2020-03-11
# 2       Games  Dinosaur Fossil Hunter     7962    Poland 2020-04-16
# 3  Film&Video        Beyond Your Eyes      276  Bulgaria 2020-02-09
# 4  Film&Video                    5150    23963       USA 2020-04-10
# 5  Film&Video              8-Bit Wars     6950        UK 2020-03-19

# %%
df.groupby(pd.Grouper(key='Date_Start',freq='ME')).sum()
# Out:
#                         Category                          Project_Title  \
# Date_Start
# 2020-02-29            Film&Video                       Beyond Your Eyes
# 2020-03-31  GamesFilm&VideoGames  Magic Puzzles8-Bit WarsThe Last Faith
# 2020-04-30       Film&VideoGames             5150Dinosaur Fossil Hunter
#
#             Pledged    Country
# Date_Start
# 2020-02-29      276   Bulgaria
# 2020-03-31  2973243    USAUKUK
# 2020-04-30    31925  USAPoland

# %%
df.groupby(pd.Grouper(key='Date_Start',freq='ME')).agg({'Pledged':'sum','Project_Title':'count'})
# Out:
#             Pledged  Project_Title
# Date_Start
# 2020-02-29      276              1
# 2020-03-31  2973243              3
# 2020-04-30    31925              2

# %% [markdown]
# Brakujące dane

# %%
df_with_nulls = pd.DataFrame({'A':[1,100,np.nan,1000,10000],
                             'B':[2,4,2,4,np.nan],
                             'C':[40,np.nan,20,np.nan,np.nan]})
df_with_nulls
# Out:
#          A    B     C
# 0      1.0  2.0  40.0
# 1    100.0  4.0   NaN
# 2      NaN  2.0  20.0
# 3   1000.0  4.0   NaN
# 4  10000.0  NaN   NaN

# %%
print(df_with_nulls.isnull().mean())
print()
print(df_with_nulls.isnull().sum())
# Out:
# A    0.2
# B    0.2
# C    0.6
# dtype: float64
#
# A    1
# B    1
# C    3
# dtype: int64

# %%
df_with_nulls[df_with_nulls['C'].isnull()] #filtrowanie jezeli NaN w kolumnie Cpip install missingno==0.4.2
# Out:
#          A    B   C
# 1    100.0  4.0 NaN
# 3   1000.0  4.0 NaN
# 4  10000.0  NaN NaN

# %%
pip install missingno
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import missingno as msno

# %%
msno.matrix(df_with_nulls)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[170], line 1
# ----> 1 msno.matrix(df_with_nulls)
#
# File ~/Code/venv312/lib/python3.12/site-packages/missingno/missingno.py:72, in matrix(df, filter, n, p, sort, figsize, width_ratios, color, fontsize, labels, sparkline, inline, freq, ax)
#      70 # Remove extraneous default visual elements.
#      71 ax0.set_aspect('auto')
# ---> 72 ax0.grid(b=False)
#      73 ax0.xaxis.tick_top()
#      74 ax0.xaxis.set_ticks_position('none')
#
# File ~/Code/venv312/lib/python3.12/site-packages/matplotlib/axes/_base.py:3347, in _AxesBase.grid(self, visible, which, axis, **kwargs)
#    3345 _api.check_in_list(['x', 'y', 'both'], axis=axis)
#    3346 if axis in ['x', 'both']:
# -> 3347     self.xaxis.grid(visible, which=which, **kwargs)
#    3348 if axis in ['y', 'both']:
#    3349     self.yaxis.grid(visible, which=which, **kwargs)
#
# ...

# %%
df_with_nulls.dropna() #usunie ona wszystkie wiersze, w których znajdzie choćby jedną brakującą wartość.
# Out:
#      A    B     C
# 0  1.0  2.0  40.0

# %%
df_with_nulls.dropna(thresh=2) #możemy sprecyzować minimalną liczbę uzupełnionych wartości w wierszu, która kwalifikuje go do pozostania w tabeli.
# Out:
#         A    B     C
# 0     1.0  2.0  40.0
# 1   100.0  4.0   NaN
# 2     NaN  2.0  20.0
# 3  1000.0  4.0   NaN

# %%
df_with_nulls.dropna(thresh=3,axis=1)
# Out:
#          A    B
# 0      1.0  2.0
# 1    100.0  4.0
# 2      NaN  2.0
# 3   1000.0  4.0
# 4  10000.0  NaN

# %%
df_with_nulls.fillna('NOWA WARTOŚĆ') #ustawia wartosc
# Out:
#               A             B             C
# 0           1.0           2.0          40.0
# 1         100.0           4.0  NOWA WARTOŚĆ
# 2  NOWA WARTOŚĆ           2.0          20.0
# 3        1000.0           4.0  NOWA WARTOŚĆ
# 4       10000.0  NOWA WARTOŚĆ  NOWA WARTOŚĆ

# %%
df_with_nulls['B'].fillna(df_with_nulls['B'].mean()) #ustawia srednia na Nan
# Out:
# 0    2.0
# 1    4.0
# 2    2.0
# 3    4.0
# 4    3.0
# Name: B, dtype: float64

# %%
df_with_nulls['A'].ffill()
# Out:
# 0        1.0
# 1      100.0
# 2      100.0
# 3     1000.0
# 4    10000.0
# Name: A, dtype: float64

# %% [markdown]
# Merge, Join, Concatenate

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],

                    'B': ['B0', 'B1', 'B2', 'B3'],

                    'C': ['C0', 'C1', 'C2', 'C3'],

                    'D': ['D0', 'D1', 'D2', 'D3']},

                    index=[0, 1, 2, 3])

df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],

                    'B': ['B4', 'B5', 'B6', 'B7'],

                    'C': ['C4', 'C5', 'C6', 'C7'],

                    'D': ['D4', 'D5', 'D6', 'D7']},

                    index=[4, 5, 6, 7])

df3 = pd.DataFrame({'A': ['A8', 'A9', 'A10', 'A11'],

                    'B': ['B8', 'B9', 'B10', 'B11'],

                    'C': ['C8', 'C9', 'C10', 'C11'],

                    'D': ['D8', 'D9', 'D10', 'D11']},

                    index=[8, 9, 10, 11])

# %%
pd.concat([df1,df2,df3]) #zestawić wszystkie trzy tabele jedna pod drugą
# Out:
#       A    B    C    D
# 0    A0   B0   C0   D0
# 1    A1   B1   C1   D1
# 2    A2   B2   C2   D2
# 3    A3   B3   C3   D3
# 4    A4   B4   C4   D4
# 5    A5   B5   C5   D5
# 6    A6   B6   C6   D6
# 7    A7   B7   C7   D7
# 8    A8   B8   C8   D8
# 9    A9   B9   C9   D9
# 10  A10  B10  C10  D10
# 11  A11  B11  C11  D11

# %%
s = pd.Series(['S1','S2','S3','S4'])

# %%
pd.concat([df1,s])
# Out:
#      A    B    C    D    0
# 0   A0   B0   C0   D0  NaN
# 1   A1   B1   C1   D1  NaN
# 2   A2   B2   C2   D2  NaN
# 3   A3   B3   C3   D3  NaN
# 0  NaN  NaN  NaN  NaN   S1
# 1  NaN  NaN  NaN  NaN   S2
# 2  NaN  NaN  NaN  NaN   S3
# 3  NaN  NaN  NaN  NaN   S4

# %%
pd.concat([df1,s],axis=1)
# Out:
#     A   B   C   D   0
# 0  A0  B0  C0  D0  S1
# 1  A1  B1  C1  D1  S2
# 2  A2  B2  C2  D2  S3
# 3  A3  B3  C3  D3  S4

# %%
pd.concat([df1,df2,df3],axis=1,keys=['first','second','third'])
# Out:
#    first                second                third
#        A    B    C    D      A    B    C    D     A    B    C    D
# 0     A0   B0   C0   D0    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 1     A1   B1   C1   D1    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 2     A2   B2   C2   D2    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 3     A3   B3   C3   D3    NaN  NaN  NaN  NaN   NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN     A4   B4   C4   D4   NaN  NaN  NaN  NaN
# 5    NaN  NaN  NaN  NaN     A5   B5   C5   D5   NaN  NaN  NaN  NaN
# 6    NaN  NaN  NaN  NaN     A6   B6   C6   D6   NaN  NaN  NaN  NaN
# 7    NaN  NaN  NaN  NaN     A7   B7   C7   D7   NaN  NaN  NaN  NaN
# 8    NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN    A8   B8   C8   D8
# 9    NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN    A9   B9   C9   D9
# 10   NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN   A10  B10  C10  D10
# 11   NaN  NaN  NaN  NaN    NaN  NaN  NaN  NaN   A11  B11  C11  D11

# %%
s = pd.Series(['S1','S2','S3','S4'])
pd.concat([df1,s])
# Out:
#      A    B    C    D    0
# 0   A0   B0   C0   D0  NaN
# 1   A1   B1   C1   D1  NaN
# 2   A2   B2   C2   D2  NaN
# 3   A3   B3   C3   D3  NaN
# 0  NaN  NaN  NaN  NaN   S1
# 1  NaN  NaN  NaN  NaN   S2
# 2  NaN  NaN  NaN  NaN   S3
# 3  NaN  NaN  NaN  NaN   S4

# %%
pd.concat([df1,df2],axis=1)
# Out:
#      A    B    C    D    A    B    C    D
# 0   A0   B0   C0   D0  NaN  NaN  NaN  NaN
# 1   A1   B1   C1   D1  NaN  NaN  NaN  NaN
# 2   A2   B2   C2   D2  NaN  NaN  NaN  NaN
# 3   A3   B3   C3   D3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   A4   B4   C4   D4
# 5  NaN  NaN  NaN  NaN   A5   B5   C5   D5
# 6  NaN  NaN  NaN  NaN   A6   B6   C6   D6
# 7  NaN  NaN  NaN  NaN   A7   B7   C7   D7

# %%
df2
# Out:
#     A   B   C   D
# 4  A4  B4  C4  D4
# 5  A5  B5  C5  D5
# 6  A6  B6  C6  D6
# 7  A7  B7  C7  D7

# %%
s
# Out:
# 0    S1
# 1    S2
# 2    S3
# 3    S4
# dtype: object

# %%
pd.concat([df1,df2.reset_index(drop=True), df3.reset_index(drop=True)],axis=1)
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  A0  B0  C0  D0  A4  B4  C4  D4   A8   B8   C8   D8
# 1  A1  B1  C1  D1  A5  B5  C5  D5   A9   B9   C9   D9
# 2  A2  B2  C2  D2  A6  B6  C6  D6  A10  B10  C10  D10
# 3  A3  B3  C3  D3  A7  B7  C7  D7  A11  B11  C11  D11

# %% [markdown]
# Merge

# %%
def make_keys(n):
    return [f'key{n}' for n in range(n)]
left = df1.copy()
left['key'] = make_keys(4)
right = df3.copy()
right['key'] = make_keys(4)

# %%
left
# Out:
#     A   B   C   D   key
# 0  A0  B0  C0  D0  key0
# 1  A1  B1  C1  D1  key1
# 2  A2  B2  C2  D2  key2
# 3  A3  B3  C3  D3  key3

# %%
right
# Out:
#       A    B    C    D   key
# 8    A8   B8   C8   D8  key0
# 9    A9   B9   C9   D9  key1
# 10  A10  B10  C10  D10  key2
# 11  A11  B11  C11  D11  key3

# %%
pd.merge(left,right,how='inner',on='key') #pomocy funkcji merge, połączymy ze sobą obie tabele na podstawie kolumny key.
# Out:
#   A_x B_x C_x D_x   key  A_y  B_y  C_y  D_y
# 0  A0  B0  C0  D0  key0   A8   B8   C8   D8
# 1  A1  B1  C1  D1  key1   A9   B9   C9   D9
# 2  A2  B2  C2  D2  key2  A10  B10  C10  D10
# 3  A3  B3  C3  D3  key3  A11  B11  C11  D11

# %%
new_right = pd.DataFrame({'E': ['E1','E2','E3','E4','E5','E6'],
                          'key': make_keys(6)})
new_right
# Out:
#     E   key
# 0  E1  key0
# 1  E2  key1
# 2  E3  key2
# 3  E4  key3
# 4  E5  key4
# 5  E6  key5

# %%
pd.merge(left,new_right,how='inner',on='key') #inner
# Out:
#     A   B   C   D   key   E
# 0  A0  B0  C0  D0  key0  E1
# 1  A1  B1  C1  D1  key1  E2
# 2  A2  B2  C2  D2  key2  E3
# 3  A3  B3  C3  D3  key3  E4

# %%
pd.merge(left,new_right,how='outer',on='key') #outer
# Out:
#      A    B    C    D   key   E
# 0   A0   B0   C0   D0  key0  E1
# 1   A1   B1   C1   D1  key1  E2
# 2   A2   B2   C2   D2  key2  E3
# 3   A3   B3   C3   D3  key3  E4
# 4  NaN  NaN  NaN  NaN  key4  E5
# 5  NaN  NaN  NaN  NaN  key5  E6

# %%
other = pd.DataFrame({'E':['E1','E2','E3','E4','E5','E6']},index=['B1','B2','B3','B4','B5','B6'])
other
# Out:
#      E
# B1  E1
# B2  E2
# B3  E3
# B4  E4
# B5  E5
# B6  E6

# %%
left.join(other,on='B')
# Out:
#     A   B   C   D   key    E
# 0  A0  B0  C0  D0  key0  NaN
# 1  A1  B1  C1  D1  key1   E1
# 2  A2  B2  C2  D2  key2   E2
# 3  A3  B3  C3  D3  key3   E3

# %%
left.join(other,on='B',how='inner')
# Out:
#     A   B   C   D   key   E
# 1  A1  B1  C1  D1  key1  E1
# 2  A2  B2  C2  D2  key2  E2
# 3  A3  B3  C3  D3  key3  E3

# %% [markdown]
# Ćwiczenie
# Użyj funkcji join, aby połączyć ze sobą tabele left oraz right według kolumny key

# %%
pd.merge(left, right, on='key', how='inner')
# Out:
#   A_x B_x C_x D_x   key  A_y  B_y  C_y  D_y
# 0  A0  B0  C0  D0  key0   A8   B8   C8   D8
# 1  A1  B1  C1  D1  key1   A9   B9   C9   D9
# 2  A2  B2  C2  D2  key2  A10  B10  C10  D10
# 3  A3  B3  C3  D3  key3  A11  B11  C11  D11
